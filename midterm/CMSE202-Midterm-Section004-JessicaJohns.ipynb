# %% [markdown]
# # CMSE 202 Midterm (Section 004 - Spring 2026)
#
# The goal of this midterm is to give you the opportunity to test out some of the skills that you've developed thus far this semester.
#
# The exam is set up so that even if you get stuck on one part there are opportunities to get points on the other parts, so consider jumping ahead if you feel like you aren't making progress and then come back later if you have time. If you have any questions during the exam, you may ask the instructor, the TA, or the LA privately: simply raise your hand and one of us will come over to you.
#
# **Permitted Resources:**
# You may use files stored locally on your own computer or on the JupyterHub server in engineering (https://jupyterhub.egr.msu.edu/). This includes any Jupyter Notebook files, code samples, or study materials that you personally created while preparing for this exam.
#
# **Prohibited Resources:**
# In accordance with the course’s Generative AI Policy, this is a closed-internet exam. You are not permitted to access any online or cloud-based resources during the exam . This restriction includes (but is not limited to):
#
# - Web searches (e.g., Google, Bing)
# - Generative AI tools or coding assistants (e.g., ChatGPT, GitHub Copilot)
# - Online forums or documentation (e.g., Stack Overflow)
# - Any other websites or shared repositories
#
# Accessing any of these resources or using an internet-enabled coding tool during the exam will result in a score of zero.  The only online interaction you are allowed is with your own github.com repositories, specific documentation links supplied directly in the exam, and through commandline downloading of needed files and packages.
#
# **Communication Restrictions:**
# All person-to-person communication tools and collaboration platforms are strictly prohibited. You may not access:
#
# - Email or chat software (e.g., Slack, Discord, Teams)
# - Shared storage or editing tools (e.g., Google Drive, Google Docs, OneDrive)
#
# Any attempt to communicate or share information during the exam will be treated as a violation of academic integrity and may also result in a score of zero.
#
# **Academic Integrity Reminder:**
# Please keep your focus on your own screen. Due to limited space, students may be seated close together—so it is essential to maintain exam integrity. You must also keep your screen brightness high enough for instructors to clearly see your activity during the exam. This is your opportunity to demonstrate your individual skills and understanding. Any suspicious or inappropriate behavior observed by the instructors may result in a disciplinary action and a zero on the exam.

# %% [markdown]
# ---
# ## Part 0: Academic integrity statement
#
# Read the following statement and edit the markdown text to put your name in the statement. This is your commitment to doing your own authentic work on this exam.

# %% [markdown]
# > I, **Jessica Johns**, affirm that this exam represents my own authetic work, without the use of any unpermitted aids or generative AIs or person-to-person communication. I understand that this exam an an opportunity to showcase my own progress in developing and improving my computational skills and have done my best to demonstrate those skills.

# %% [markdown]
# ## Part 1: Add to your Git repository to track your progress on your exam (7 points total)
#
# Before you get to far along in the exam, you're going to add it to the `cmse202-s26-turnin` repository you created in class (or in Homework 1) so that you can track your progress on the exam and preserve the final version that you turn in. In order to do this you need to
#
# 1. Navigate to your `cmse202-s26-turnin` repository and create a new directory called `midterm`.
# 2. Move this notebook into that **new directory** in your repository, then **add it and commit it to your repository**.
# 3. Finally, to test that everything is working, "git push" the file so that it ends up in your GitHub repository.
#
# **Important**: Double check you've added your Professor and your TA as collaborators to your "turnin" respository (you should have done this in the previous homework assignment).
#
# **Important**: Make sure that the version of this notebook that you are working on is the same one that you just added to your repository! If you are working on a different copy of the noteobok, **none of your changes will be tracked**!
#
# The file should now show up on your GitHub account in the `cmse202-s26-turnin` repository inside the `midterm` directory you just created.  Periodically, **you'll be asked to commit your changes to the repository and push them to the remote GitHub location**. It can be good to get into a habit of committing your changes any time you make a significant modification.

# %% [markdown]
# &#9989; **Question 1.1 Put all the Git commands you used to add your midterm folder and file to your GitHub repository (1 point)**:

# %% [markdown]
# &#9989; **Do this**:
# ```
# johnsje6@ganymede:~/CMSE202/CMSE202-s26-turnin mkdir midterm
# johnsje6@ganymede:~/CMSE202/CMSE202-s26-turnin/midterm$ git add CMSE202-Midterm-Section004-JessicaJohns.ipynb
# johnsje6@ganymede:~/CMSE202/CMSE202-s26-turnin/midterm$ git commit -m "midterm first commit"
# johnsje6@ganymede:~/CMSE202/CMSE202-s26-turnin/midterm$ git push
# ```

# %% [markdown]
# &#9989; **Question 1.2 Put the code the instructor will need to clone your repository here (1 point)**:

# %%
### Put your code here:
# !git clone https://github.com/johnsje6/CMSE202-s26-turnin.git
# Out:
# fatal: destination path 'CMSE202-s26-turnin' already exists and is not an empty directory.

# %% [markdown]
# &#9989; **Question 1.3 How can you tell if your git repository is properly set up and tracking changes? What command would you use to check this? (there could be multiple answers) (1 point)**:

# %% [markdown]
# &#9989; **Do this**:
# ```
# git status
# ```

# %% [markdown]
# &#9989; **Question 1.4 (4 points)**: After completing each of Part 1, Part 2, Part 3, and Part 4 below, save your notebook, commit the changes to your Git repository using a descriptive commit message, and push the changes to GitHub. Note that there are large &#128721; **STOP** signs reminding you to do this after each part.

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## Part 2: Downloading and analyzing unfamiliar data (10 points)

# %% [markdown]
# &#9989; **Question 2.1 (1 point)**:
# Download the file `SAS.csv` using `curl` available at this URL: `https://raw.githubusercontent.com/huichiayu/cmse_202_802/main/data/SAS.csv`). Put the command you used to download the files in the cell below.

# %%
### Put your code here: 
#curl -O https://raw.githubusercontent.com/huichiayu/cmse_202_802/main/data/SAS.csv

# %% [markdown]
# &#9989; **Question 2.2 (1 point)**: This file is a dataset of diabetic patients. Use pandas to import and display the first 10 rows of this data.
#
# **Reminder:** You can access help for python packages and methods using the `help()` function--This is an allowable use for this exam. For example, you can run `help(pandas)` to get help on the pandas package. And, you can run `help(pandas.my_favorite_example_method)` to get help on the `my_favorite_example_method` method in pandas (which doesn't exist).
#
# And, you can also use `dir()` to get a list of all the methods and attributes of a package or object. For example, you can run `dir(pandas)` to get a list of all the methods and attributes in the pandas package, and you can run `dir(pandas.DataFrame)` to get a list of all the methods and attributes of the DataFrame class in pandas.

# %%
### Put your code here:
import pandas as pd
sas = pd.read_csv("SAS.csv")

sas.head(10)
# Out:
#    AGE  SEX   BMI  Blood_pressure  Total_cholesterol  LD_lipo  HD_lipo  \
# 0   59    2  32.1           101.0                157     93.2     38.0
# 1   48    1  21.6            87.0                183    103.2     70.0
# 2   72    2  30.5            93.0                156     93.6     41.0
# 3   24    1  25.3            84.0                198    131.4     40.0
# 4   50    1  23.0           101.0                192    125.4     52.0
# 5   23    1  22.6            89.0                139     64.8     61.0
# 6   36    2  22.0            90.0                160     99.6     50.0
# 7   66    2  26.2           114.0                255    185.0     56.0
# 8   60    2  32.1            83.0                179    119.4     42.0
# 9   29    1  30.0            85.0                180     93.4     43.0
#
#    Total_cholesterol/HDL  triglycerides  Glucose    Y
# 0                   4.00         4.8598       87  151
# 1                   3.00         3.8918       69   75
# ...

# %% [markdown]
# &#9989; **Question 2.3 (1 point)**: This dataset contains many samples (rows) and several variables (columns) for each sample. How many samples and variables are in this dataset?

# %%
### Put your code here:
print(len(sas)) #Rows(samples)
print(len(sas.columns)) #Columns(variables)
# Out:
# 442
# 11

# %% [markdown]
# &#9989; **Question 2.4 (2 points)**: We want to analyze the data of male and female patients separately. Group the data by the "SEX" column and then use the built-in Pandas function to get a quick statistical summary of your data (e.g. the mean, standard deviation, min, max, etc).  Hint: You can use the `groupby()` method in pandas to group the data.

# %%
### Put your code here
sas_sex=(sas.groupby(pd.Grouper(key="SEX")))
sas_sex.describe()
# Out:
#        AGE                                                        BMI  \
#      count       mean        std   min   25%   50%   75%   max  count
# SEX
# 2    207.0  50.942029  12.697623  20.0  41.0  53.0  60.0  79.0  207.0
# 1    235.0  46.382979  13.120665  19.0  37.0  48.0  55.0  75.0  235.0
#
#                 ... Glucose             Y                                     \
#           mean  ...     75%    max  count        mean        std   min   25%
# SEX             ...
# 2    26.790338  ...   100.5  124.0  207.0  155.666667  78.453313  39.0  88.0
# 1    26.010638  ...    96.0  124.0  235.0  149.021277  75.905781  25.0  85.5
#
#
#        50%    75%    max
# SEX
# 2    141.0  220.5  341.0
# 1    140.0  200.0  346.0
#
# [2 rows x 80 columns]

# %% [markdown]
# &#9989; **Question 2.5 (3 point)**: Let's analyze the correlation between BMI and Glucose of the male patients (SEX = 1). Extract the data of male patients and make a scatter plot of Glucose versus BMI. Make sure to include labels and a title for your plot.

# %%
### Put your code here
import matplotlib.pyplot as plt
sas_men = sas[sas['SEX'] == 1]

plt.figure(figsize=(10,6))
plt.scatter(sas_men['Glucose'], sas_men['BMI'], marker='o') 

plt.xlabel('Glucose')
plt.ylabel('BMI')
plt.title('Glucose vs BMI in men ')
plt.grid(True)

plt.show()

# %% [markdown]
# &#9989; **Question 2.6 (2 points)**: Make a scatter plot of Glucose versus Age for all patients. Make sure to label the axes and include a title for your plot. Do you see any trends in the data? Describe your observations of trends in a few sentences below.

# %%
### Put your code here and your observations about the plot here
plt.figure(figsize=(10,6))
plt.scatter(sas['Glucose'], sas['AGE'], marker='o') 

plt.xlabel('Glucose')
plt.ylabel('Age')
plt.title('Glucose vs Age ')
plt.grid(True)

plt.show()
#This graph is very random, yet if you look closely, then you can see that there is a small correlation between Age and Glucose. 
#You can infer that as you age, your glucose levels raise yet this is not a strong correlation, but it does show slightly in the graph.

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## Part 3: Working with a new Python package (12 points)

# %% [markdown]
# In this part of the exam, you will install a Python package that you probably have not used before, and use it to perform a simple task. Specifically, you will use a package called `Faker` to perform some tasks that involve generating different types of fake data. The documentation and some example code can be found at https://faker.readthedocs.io/en/master/ (You are allowed to visit all of the pages on this website (and only this website) to learn about this package).

# %% [markdown]
# &#9989; **Question 3.1 (1 points)**: The `faker` package is probably not already installed on your machine. However, you should be able to install the package in the same way we have used previously to install Python packages.
#
# **Do this**: Install the `faker` Python package.
#
# What command did you use to install `faker`? **Include this command in the cell below.**

# %%
# Put your code here
#pip install faker

# %% [markdown]
# Once `faker` is installed, running the following cell should not result in an error message. **You might need to re-start your Jupyter kernel after installing the package for this to work.** (Once everything works, it should give you no output at all.)

# %%
# Running this cell should just work and not yield any output if faker is installed and available
from faker import Faker

# %% [markdown]
# &#9989; **Question 3.2 (5 points total)**: Using the `faker` package, do the following simple tasks. Each task should only require a very short amount of code, and the documentation should cover how to do it.
#
# &#9989; **Question 3.2.1 (1 point)**: Using the `faker` package, generate a fake name.

# %%
# Put your code for Question 3.2.1 here
fake = Faker()

fake.name()
# Out:
# 'Collin Miller'

# %% [markdown]
# &#9989; **Question 3.2.2 (1 point)**: Using the `faker` package, generate a fake mailing address with a Japanese locale in Japanese.

# %%
# Put your code for Question 3.2.2 here
fake_jap = Faker(['ja_JP'])
print(fake_jap.address())
# Out:
# 大分県四街道市箪笥町6丁目17番1号

# %% [markdown]
# &#9989; **Question 3.2.3 (1 point)**: Using the `faker` package, generate a fake email address.

# %%
# Put your code for Question 3.2.3 here
print(fake.email())
# Out:
# david80@example.net

# %% [markdown]
# &#9989; **Question 3.2.4 (1 point)**: Using the `faker` package, generate a fake company name.

# %%
# Put your code for Question 3.2.4 here
print(fake.company())
# Out:
# Proctor, Richardson and Blackwell

# %% [markdown]
# &#9989; **Question 3.2.5 (1 point)**: Using the `faker` package, generate a fake date.

# %%
# Put your code for Question 3.2.5 here
print(fake.date())
# Out:
# 1987-10-15

# %% [markdown]
# &#9989; **Question 3.3 (6 points)**: Now that you've had a bit of practice with the `faker` package, let's make a fake database using United States addresses and names. Create a `Pandas` `DataFrame` with 40 rows and the columns `"Name"`, `"Date of Birth"`, `"Address"`, `"Email"`, and `"Employer"`. Then, populate the rows with fake data that is appropriate for the column (so the `"Name"` column should look like a name, the `"Date of Birth"` column should look like a date, etc. Don't worry if some of the fake people you generate are too old/young to be employed). Finally, display the `DataFrame`.

# %%
# Put your code for Question 3.3 here
fake_US = Faker(['en_US'])
fake_df = []
for _ in range(40):
    fake_df.append({"Name": fake_US.unique.name(), "Date of Birth": fake_US.date(), "Address": fake_US.unique.address(), 
                 "Email": fake_US.unique.email(), "Employer": fake_US.company()})

fake_info = pd.DataFrame(fake_df)
fake_info
# Out:
#                   Name Date of Birth  \
# 0         Alison Young    1971-12-06
# 1         Heather Pope    1972-04-03
# 2      Christina Velez    2020-02-29
# 3        Cathy Johnson    1986-03-17
# 4          Peter Davis    2003-09-04
# 5        Amy Henderson    2010-12-29
# 6         Shari Weaver    1992-08-28
# 7          James Baker    2005-09-21
# 8        Madison Lopez    1994-03-25
# 9         Briana Smith    2002-05-25
# 10    Courtney Johnson    1980-12-06
# 11          Daniel Lee    1976-08-18
# 12  Nicholas Mcconnell    1983-07-31
# 13        Deborah Kidd    2018-07-13
# 14       Sean Gonzalez    2017-09-14
# 15           Mary Hale    2023-06-12
# 16       Jasmine Mccoy    2021-10-08
# 17        Derek Murphy    2010-04-27
# 18   Jeanette Carrillo    1971-12-24
# 19    Richard Phillips    2013-07-27
# 20    Matthew Gonzales    2001-06-11
# 21      Susan Martinez    2013-03-28
# 22     Bethany Jimenez    1994-09-29
# 23         Morgan Odom    2000-09-17
# ...

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## Part 4: Writing a Python class (11 points)

# %% [markdown]
# In this part of the exam, you will debug and expand a `BankAccount` class, which is used to keep track of the balance of someone's bank account. A `BankAccount` object should have the owner's name as an attribute and be initialized to have a balance of \$0. `BankAccount` objects should also have methods to print the balance, deposit money, and withdraw money.

# %%
# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL
# This cell contains a minimally functional BankAccount class
# If you cannot get Question 4.1, you can use this BankAccount class for Question 4.2 
class BankAccount:
    def __init__(self,name):
        self.name = name
        self.balance = 0
    
    def print_balance(self):
        print(self.balance)
    
    def deposit(self,amount):
        self.balance += amount
        
    def withdraw(self,amount):
        self.balance -= amount
# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL

# %% [markdown]
# &#9989; **Question 4.1 [11 points]**: **Do this**: Debug and expand the `BankAccount` class in the code cell below using the following instructions:
#
# * The `__init__()` method should have two arguments `name` and `account_login` (along with the argument all class methods have).
#     * It should create a `BankAccount` object with three attributes: `name`, `account_login`, and `balance`.
#     * The `name` attribute should be initialized to the `name` argument.
#     * The `account_login` attribute should be initialized to the `account_login` argument or to a default value if `account_login` is not provided.
#     * The `balance` attribute should be set to `0`.
#     * It should print something like "[NAME] with account [ACCOUNT_LOGIN] has opened a bank account."
# * The `print_balance()` method should have no arguments (except what all class methods have).
#     * It should print something like "[NAME] has \$[BALANCE] in their bank account."
# * The `deposit()` method should have one argument `amount` (along with the argument all class methods have).
#     * It should increase the `balance` by `amount`, and then print something like "\$[AMOUNT] succesfully deposited into account."
# * The `withdraw()` method should have one argument `amount` (along with the argument all class methods have).
#     * If the `balance` attribute is at least `amount`, it should decrease `balance` by `amount`, and then print something like "\$[AMOUNT] succesfully withdrawn from account."
#     * If the `balance` attribute is less than `amount`, it should print something like "Error: Bank balance is insufficient." and leave the `balance` attribute unchanged.

# %%
# Debug and expand this BankAccount class to meet the specifications in Question 4.1
class BankAccount:
    def __init__(self, name, account_login):
        self.name = name
        self.balance = 0
        self.account_login = account_login
        print(self.name," with account_login ",self.account_login," has opened a bank account.",sep='')
        
    def print_balance(self):
        print(self.name," has $",self.balance," in their bank account.",sep='')
    
    def deposit(self, amount):
        self.balance += amount
        print("$",amount," successfully deposited into account.",sep='')
        
    def withdraw(self, amount):
        if(self.balance >= amount):
            self.balance -= amount
            print("$",amount," successfully withdrawn from account.",sep='')
        else:
            print("Error: Bank balance is insufficient")

# %% [markdown]
# &#9989; **Do this**: When you are done editing the `BankAccount` class, you can run the cell below to test it out. Your output should look like this:
#
# ```
# Bob with account_login bob123 has opened a bank account.
# Bob has $0 in their bank account.
# $100 succesfully deposited into account.
# Bob has $100 in their bank account.
# $100 succesfully withdrawn from account.
# Bob has $0 in their bank account.
# $25 succesfully deposited into account.
# Bob has $25 in their bank account.
# Error: Bank balance insufficient!
# Bob has $25 in their bank account.
# ```

# %%
# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL
account = BankAccount("Bob", "bob123")
account.print_balance()
account.deposit(100)
account.print_balance()
account.withdraw(100)
account.print_balance()
account.deposit(25)
account.print_balance()
account.withdraw(400)
account.print_balance()
# DO NOT EDIT THIS CELL
# DO NOT EDIT THIS CELL
# Out:
# Bob with account_login bob123 has opened a bank account.
# Bob has $0 in their bank account.
# $100 successfully deposited into account.
# Bob has $100 in their bank account.
# $100 successfully withdrawn from account.
# Bob has $0 in their bank account.
# $25 successfully deposited into account.
# Bob has $25 in their bank account.
# Error: Bank balance is insufficient
# Bob has $25 in their bank account.

# %% [markdown]
# ---
# ### &#128721; STOP (1 point)
# **Pause to commit your changes to your Git repository!**
#
# Take a moment to save your notebook, commit  and push the changes to your Git repository.
#
# ---

# %% [markdown]
# ## You're done! Congrats on finishing your CMSE 202 Midterm!
#
# Make sure all of your changes to your repository are committed and pushed to GitHub. Also upload a copy of this notebook to the dropbox on D2L in case something went wrong with your repository or if you couldn't get the repository to work.
